# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    shot_id_number  match_event_id  location_x  location_y  remaining_min  \
# 0             1.0            10.0       167.0        72.0           10.0
# 1             2.0            12.0      -157.0         0.0           10.0
# 2             3.0            35.0      -101.0       135.0            7.0
# 3             4.0            43.0       138.0       175.0            6.0
# 4             5.0           155.0         0.0         0.0            NaN
#
#    power_of_shot  knockout_match game_season  remaining_sec  distance_of_shot  \
# 0            1.0             0.0     2000-01           27.0              38.0
# 1            1.0             0.0     2000-01           22.0              35.0
# 2            1.0             0.0     2000-01           45.0              36.0
# 3            1.0             0.0     2000-01           52.0              42.0
# 4            2.0             0.0     2000-01           19.0              20.0
#
#    ... type_of_shot type_of_combined_shot  match_id     team_id  \
# 0  ...    shot - 30                   NaN  20000012  1610612747
# 1  ...    shot - 45                   NaN  20000012  1610612747
# 2  ...    shot - 25                   NaN  20000012  1610612747
# 3  ...          NaN              shot - 3  20000012  1610612747
# 4  ...          NaN              shot - 1  20000012  1610612747
#
#   remaining_min1 power_of_shot1  knockout_match_1 remaining_sec1  \
# 0          10.00            1.0            50.608        54.2000
# 1          10.00            1.0            28.800        22.0000
# 2          92.64            1.0             0.000        63.7216
# 3            NaN            1.0           122.608        52.0000
# 4          42.64            2.0             0.000        19.0000
#
#   distance_of_shot_1 is_goal
# 0               38.0     NaN
# 1               35.0     0.0
# 2               54.4     1.0
# 3               42.0     0.0
# 4               20.0     1.0
#
# [5 rows x 28 columns]

# %%
data.describe()
# Out:
#        shot_id_number  match_event_id    location_x    location_y  \
# count    30696.000000    29134.000000  29236.000000  29157.000000
# mean     15348.500000      249.576028      7.383876     91.126933
# std       8861.316268      150.186019    110.263049     87.676395
# min          1.000000        2.000000   -250.000000    -44.000000
# 25%       7674.750000      111.000000    -68.000000      4.000000
# 50%      15348.500000      254.000000      0.000000     74.000000
# 75%      23022.250000      369.000000     95.000000    160.000000
# max      30696.000000      659.000000    248.000000    791.000000
#
#        remaining_min  power_of_shot  knockout_match  remaining_sec  \
# count   29135.000000   29211.000000    29180.000000   29103.000000
# mean        4.883233       2.519359        0.145956      28.329382
# std         3.452533       1.153976        0.353068      17.470663
# min         0.000000       1.000000        0.000000       0.000000
# 25%         2.000000       1.000000        0.000000      13.000000
# 50%         5.000000       3.000000        0.000000      28.000000
# 75%         8.000000       3.000000        0.000000      43.000000
# max        11.000000       7.000000        1.000000      59.000000
#
#        distance_of_shot  shot_id_number_1      match_id       team_id  \
# count      29130.000000      29134.000000  3.069700e+04  3.069700e+04
# mean          33.448884      15368.581039  2.476407e+07  1.610613e+09
# std            9.369656       8866.520772  7.755175e+06  0.000000e+00
# min           20.000000          1.000000  2.000001e+07  1.610613e+09
# 25%           25.000000       7693.250000  2.050008e+07  1.610613e+09
# 50%           35.000000      15378.500000  2.090035e+07  1.610613e+09
# 75%           41.000000      23055.750000  2.960047e+07  1.610613e+09
# max           99.000000      30697.000000  4.990009e+07  1.610613e+09
#
#        remaining_min1  power_of_shot1  knockout_match_1  remaining_sec1  \
# count    29162.000000    29158.000000      29204.000000    29158.000000
# mean        18.204615       15.994109         16.599402       39.027303
# std         29.416973       29.676815         35.172016       29.835284
# min          0.000000        1.000000          0.000000        0.000000
# 25%          3.000000        2.000000          0.000000       17.000000
# 50%          6.000000        3.000000          0.000000       35.000000
# 75%         11.000000        4.000000          1.000000       52.000000
# max        128.761600      118.360000        141.352320      144.785600
#
#        distance_of_shot_1       is_goal
# count        29129.000000  24429.000000
# mean            38.801852      0.445331
# std             18.787711      0.497013
# min              9.400000      0.000000
# 25%             26.000000      0.000000
# 50%             36.000000      0.000000
# 75%             44.000000      1.000000
# max            115.728000      1.000000

# %%
data['remaining_min'] = data['remaining_min'].fillna(data['remaining_min1'])
data['power_of_shot'] = data['power_of_shot'].fillna(data['power_of_shot1'])
data['knockout_match'] = data['knockout_match'].fillna(data['knockout_match_1'])
data['remaining_sec'] = data['remaining_sec'].fillna(data['remaining_sec1'])
data['distance_of_shot'] = data['distance_of_shot'].fillna(data['distance_of_shot_1'])
data['type_of_shot'] = data['type_of_shot'].fillna(data['type_of_combined_shot'])
# data = data.drop(columns=['match_id','team_id','lat/lng','team_name','match_event_id','game_season','date_of_game','shot_id_number_1'])
data = data.drop(columns = ['remaining_min1','power_of_shot1','knockout_match_1','remaining_sec1','distance_of_shot_1','type_of_combined_shot'])
data = data.drop(columns = ['shot_id_number_1','team_name','team_id','match_event_id','lat/lng','match_id'])
cols = ['remaining_min','power_of_shot','knockout_match','remaining_sec','distance_of_shot']
data.head()
#data.type_of_shot.isna().sum()
# Out:
#    shot_id_number  location_x  location_y  remaining_min  power_of_shot  \
# 0             1.0       167.0        72.0          10.00            1.0
# 1             2.0      -157.0         0.0          10.00            1.0
# 2             3.0      -101.0       135.0           7.00            1.0
# 3             4.0       138.0       175.0           6.00            1.0
# 4             5.0         0.0         0.0          42.64            2.0
#
#    knockout_match game_season  remaining_sec  distance_of_shot  \
# 0             0.0     2000-01           27.0              38.0
# 1             0.0     2000-01           22.0              35.0
# 2             0.0     2000-01           45.0              36.0
# 3             0.0     2000-01           52.0              42.0
# 4             0.0     2000-01           19.0              20.0
#
#             area_of_shot shot_basics    range_of_shot date_of_game  \
# 0          Right Side(R)   Mid Range        16-24 ft.   31-10-2000
# 1           Left Side(L)   Mid Range         8-16 ft.   31-10-2000
# 2   Left Side Center(LC)   Mid Range        16-24 ft.   31-10-2000
# 3  Right Side Center(RC)   Mid Range        16-24 ft.   31-10-2000
# 4              Center(C)   Goal Area  Less Than 8 ft.   31-10-2000
#
#   home_or_away type_of_shot  is_goal
# 0   MANU @ POR    shot - 30      NaN
# 1   MANU @ POR    shot - 45      0.0
# 2          NaN    shot - 25      1.0
# 3   MANU @ POR     shot - 3      0.0
# 4   MANU @ POR     shot - 1      1.0

# %%
import seaborn as sns
correlation_matrix = data.corr()
fig = plt.figure(figsize = (12,9))
sns.heatmap(correlation_matrix,vmax = 0.8,square = True)
plt.show()

# %%
# Performing winsorization on some of the columns 
for col in cols:
    quantile1 = data[col].quantile(0.95)
    quantile2 = data[col].quantile(0.05)
    data[col] = data[col].clip(quantile2,quantile1)
data.describe()
# Out:
#        shot_id_number    location_x    location_y  remaining_min  \
# count    30696.000000  29236.000000  29157.000000   30616.000000
# mean     15348.500000      7.383876     91.126933       4.942546
# std       8861.316268    110.263049     87.676395       3.486564
# min          1.000000   -250.000000    -44.000000       0.000000
# 25%       7674.750000    -68.000000      4.000000       2.000000
# 50%      15348.500000      0.000000     74.000000       5.000000
# 75%      23022.250000     95.000000    160.000000       8.000000
# max      30696.000000    248.000000    791.000000      11.000000
#
#        power_of_shot  knockout_match  remaining_sec  distance_of_shot  \
# count   30627.000000    30623.000000   30620.000000      30600.000000
# mean        2.519313        0.154753      28.628892         33.368774
# std         1.131343        0.361675      17.476336          9.034560
# min         1.000000        0.000000       1.000000         20.000000
# 25%         1.000000        0.000000      13.000000         25.000000
# 50%         3.000000        0.000000      29.000000         35.000000
# 75%         4.000000        0.000000      44.000000         41.000000
# max         4.000000        1.000000      57.000000         46.000000
#
#             is_goal
# count  24429.000000
# mean       0.445331
# std        0.497013
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
data['home_or_away'] = data['home_or_away'].fillna(method = 'bfill')
data['shot_basics'] = data['shot_basics'].fillna(method = 'bfill')
data['range_of_shot'] = data['range_of_shot'].fillna(method = 'bfill')
data['area_of_shot'] = data['area_of_shot'].fillna(method = 'bfill' )

# data['match_id'] = data['match_id'].fillna(method = 'bfill' )
# data['lat/lng'] = data['lat/lng'].fillna(method = 'bfill' )
# data['match_event_id'] = data['match_event_id'].fillna(method = 'bfill' )
data['game_season'] = data['game_season'].fillna(method = 'bfill' )
data['date_of_game'] = data['date_of_game'].fillna(method = 'bfill' )
print(data.shape)
# Out:
# (30697, 16)

# %%
means = dict(data.mean())
medians = dict(data.median())
print('Means: ',means)
print('Medians: ',medians)

data['location_x'] = data['location_x'].fillna(means['location_x'])
data['location_y'] = data['location_y'].fillna(means['location_y'])
data['remaining_min'] = data['remaining_min'].fillna(means['remaining_min'])
data['power_of_shot'] = data['power_of_shot'].fillna(means['power_of_shot'])
data['knockout_match'] = data['knockout_match'].fillna(medians['knockout_match'])
data['remaining_sec'] = data['remaining_sec'].fillna(means['remaining_sec'])
data['distance_of_shot'] = data['distance_of_shot'].fillna(means['distance_of_shot'])
# Out:
# Means:  {'shot_id_number': 15348.5, 'location_x': 7.383876043234369, 'location_y': 91.12693349795933, 'remaining_min': 4.942546380977267, 'power_of_shot': 2.519313024455546, 'knockout_match': 0.15475296345883813, 'remaining_sec': 28.628891652514696, 'distance_of_shot': 33.36877437908497, 'is_goal': 0.4453313684555242}
# Medians:  {'shot_id_number': 15348.5, 'location_x': 0.0, 'location_y': 74.0, 'remaining_min': 5.0, 'power_of_shot': 3.0, 'knockout_match': 0.0, 'remaining_sec': 29.0, 'distance_of_shot': 35.0, 'is_goal': 0.0}

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder  = LabelEncoder()
data['shot_basics']=  labelencoder.fit_transform(data['shot_basics'])
data['range_of_shot']=  labelencoder.fit_transform(data['range_of_shot'])
data['area_of_shot']=  labelencoder.fit_transform(data['area_of_shot'])
data['type_of_shot']=  labelencoder.fit_transform(data['type_of_shot'])



# data['match_id'] = labelencoder.fit_transform(data['match_id'])
# data['lat/lng'] = labelencoder.fit_transform(data['lat/lng'])
# data['match_event_id'] = labelencoder.fit_transform(data['match_event_id'])
data['game_season'] = labelencoder.fit_transform(data['game_season'])

data['day'] = pd.DatetimeIndex(data['date_of_game']).day
data['month'] = pd.DatetimeIndex(data['date_of_game']).month
data['year'] = pd.DatetimeIndex(data['date_of_game']).year
data = data.drop(columns = ['date_of_game'])

data['day'] = labelencoder.fit_transform(data['day'])
data['month'] = labelencoder.fit_transform(data['month'])
data['year'] = labelencoder.fit_transform(data['year'])

"""
print(x_td[0:3,:])
onehotencoder = OneHotEncoder(categorical_features =[0,2,4,5,9])
x_td= onehotencoder.fit_transform(x_td).toarray()
print(x_td[0,:])

"""
# Out:
# '\nprint(x_td[0:3,:])\nonehotencoder = OneHotEncoder(categorical_features =[0,2,4,5,9])\nx_td= onehotencoder.fit_transform(x_td).toarray()\nprint(x_td[0,:])\n\n'

# %%
home_team = data['home_or_away']
home_team = list(home_team)
labels  = []
for team in home_team:
    if '@' in team.split(' '):
        labels.append(1)
    else :
        labels.append(0)
data['home_or_away'] = pd.Series(labels).astype('float64')

# %%
train1 = data[data['is_goal']==1]
train2 = data[data['is_goal']==0]
print(train1.shape)
print(train2.shape)
train = train1.append(train2)
test = data[data['is_goal']!=1]
test = test[test['is_goal']!=0]
print(test.shape)
# Out:
# (10879, 18)
# (13550, 18)
# (6268, 18)

# %%
test.head()
# Out:
#     shot_id_number  location_x  location_y  remaining_min  power_of_shot  \
# 0              1.0       167.0        72.0           10.0            1.0
# 7              8.0         1.0        28.0            8.0            3.0
# 16            17.0         0.0         0.0            0.0            1.0
# 19            20.0         0.0         0.0           10.0            3.0
# 21            22.0       134.0       127.0            9.0            3.0
#
#     knockout_match  game_season  remaining_sec  distance_of_shot  \
# 0              0.0            4           27.0              38.0
# 7              0.0            4            5.0              22.0
# 16             0.0            4            1.0              20.0
# 19             0.0            4           46.0              20.0
# 21             0.0            4            4.0              38.0
#
#     area_of_shot  shot_basics  range_of_shot  home_or_away  type_of_shot  \
# 0              5            4              0           1.0            24
# 7              0            0              4           1.0            23
# 16             1            0              4           0.0            34
# 19             0            4              4           0.0            34
# 21             4            4              0           0.0            17
#
#     is_goal  day  month  year
# 0       NaN   26      9     4
# 7       NaN   26      9     4
# 16      NaN    6      0     4
# 19      NaN    6      0     4
# 21      NaN    6      0     4

# %%
train.head()
# Out:
#     shot_id_number  location_x  location_y  remaining_min  power_of_shot  \
# 2              3.0      -101.0  135.000000            7.0            1.0
# 4              5.0         0.0    0.000000           11.0            2.0
# 6              7.0         0.0    0.000000            8.0            3.0
# 8              9.0       -65.0   91.126933            6.0            3.0
# 11            12.0       121.0  127.000000           11.0            1.0
#
#     knockout_match  game_season  remaining_sec  distance_of_shot  \
# 2              0.0            4           45.0              36.0
# 4              0.0            4           19.0              20.0
# 6              0.0            4           52.0              20.0
# 8              0.0            4           12.0              32.0
# 11             0.0            4            1.0              37.0
#
#     area_of_shot  shot_basics  range_of_shot  home_or_away  type_of_shot  \
# 2              1            4              0           1.0            18
# 4              0            0              4           1.0             1
# 6              0            0              4           1.0            34
# 8              2            1              2           1.0            30
# 11             4            4              0           0.0            23
#
#     is_goal  day  month  year
# 2       1.0   26      9     4
# 4       1.0   26      9     4
# 6       1.0   26      9     4
# 8       1.0   26      9     4
# 11      1.0    6      0     4

# %%
data.hist(figsize = (20,15))
plt.show()

# %%
test.describe()
# Out:
#        shot_id_number   location_x   location_y  remaining_min  power_of_shot  \
# count     6268.000000  6268.000000  6268.000000    6268.000000    6268.000000
# mean     15423.616784     6.974327    89.890626       4.951540       2.515595
# std       8864.689203   108.072921    84.185374       3.472344       1.135768
# min          1.000000  -246.000000   -44.000000       0.000000       1.000000
# 25%       7766.750000   -60.000000     5.000000       2.000000       1.000000
# 50%      15396.500000     0.000000    83.000000       5.000000       3.000000
# 75%      23182.750000    90.000000   154.000000       8.000000       4.000000
# max      30694.000000   248.000000   592.000000      11.000000       4.000000
#
#        knockout_match  game_season  remaining_sec  distance_of_shot  \
# count     6268.000000  6268.000000    6268.000000       6268.000000
# mean         0.154914     9.291002      28.860127         33.300755
# std          0.361851     4.900497      17.313894          9.092946
# min          0.000000     0.000000       1.000000         20.000000
# 25%          0.000000     5.000000      14.000000         24.000000
# 50%          0.000000     9.000000      29.000000         35.000000
# 75%          0.000000    13.000000      44.000000         41.000000
# max          1.000000    19.000000      57.000000         46.000000
#
#        area_of_shot  shot_basics  range_of_shot  home_or_away  type_of_shot  \
# count    6268.00000  6268.000000    6268.000000   6268.000000   6268.000000
# mean        1.76053     2.782706       1.864869      0.508775     26.451340
# std         1.94407     1.989603       1.599353      0.499963     11.528447
# min         0.00000     0.000000       0.000000      0.000000      0.000000
# 25%         0.00000     1.000000       0.000000      0.000000     23.000000
# 50%         1.00000     4.000000       2.000000      1.000000     23.000000
# 75%         4.00000     4.000000       4.000000      1.000000     34.000000
# max         5.00000     6.000000       4.000000      1.000000     56.000000
#
#        is_goal          day        month         year
# count      0.0  6268.000000  6268.000000  6268.000000
# mean       NaN    10.897096     5.086152     9.984525
# std        NaN     7.818373     3.943908     4.867406
# min        NaN     0.000000     0.000000     0.000000
# 25%        NaN     4.000000     2.000000     6.000000
# 50%        NaN    10.000000     4.000000    10.000000
# 75%        NaN    17.000000    10.000000    14.000000
# max        NaN    26.000000    11.000000    20.000000

# %%
train.shape
# Out:
# (24429, 18)

# %%
train = train.drop(columns = ['day','month','year','location_y','distance_of_shot'])
train.head()
# Out:
#     shot_id_number  location_x  remaining_min  power_of_shot  knockout_match  \
# 2              3.0      -101.0            7.0            1.0             0.0
# 4              5.0         0.0           11.0            2.0             0.0
# 6              7.0         0.0            8.0            3.0             0.0
# 8              9.0       -65.0            6.0            3.0             0.0
# 11            12.0       121.0           11.0            1.0             0.0
#
#     game_season  remaining_sec  area_of_shot  shot_basics  range_of_shot  \
# 2             4           45.0             1            4              0
# 4             4           19.0             0            0              4
# 6             4           52.0             0            0              4
# 8             4           12.0             2            1              2
# 11            4            1.0             4            4              0
#
#     home_or_away  type_of_shot  is_goal
# 2            1.0            18      1.0
# 4            1.0             1      1.0
# 6            1.0            34      1.0
# 8            1.0            30      1.0
# 11           0.0            23      1.0

# %%
y  = train.iloc[:,12].values
train  = train.drop(columns = ['is_goal'])
X = train.iloc[:,:].values
print(X.shape)
print(y.shape)
# Out:
# (24429, 12)
# (24429,)

# %%
onehotencoder = OneHotEncoder(categorical_features =[6,7,8,10])
X = onehotencoder.fit_transform(X[:,1:]).toarray()
# Out:
# C:\Users\accsu\Anaconda3\envs\keras-gpu\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\accsu\Anaconda3\envs\keras-gpu\lib\site-packages\sklearn\preprocessing\_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X[:,1:])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10)
X_train.shape
# Out:
# (21986, 81)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train,y_train)
# Out:
# C:\Users\accsu\Anaconda3\envs\keras-gpu\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5) * 1
y_pred
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(y_test)
# Out:
# [1. 1. 0. ... 0. 0. 0.]

# %%
cm
# Out:
# array([[1004,  334],
#        [ 632,  473]], dtype=int64)

# %%
from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential()

classifier.add(Dense(units = 64,activation='relu',input_dim=81,init='glorot_uniform'))
classifier.add(Dense(units = 32,activation='relu',init='glorot_uniform'))
classifier.add(Dense(units = 16,activation='relu',init='glorot_uniform'))
classifier.add(Dense(units = 1,activation='sigmoid',init='glorot_uniform'))
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

classifier.fit(X_train,y_train,batch_size=256,epochs=10)
# Out:
# C:\Users\accsu\Anaconda3\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=64, activation="relu", input_dim=81, kernel_initializer="glorot_uniform")`
#
# C:\Users\accsu\Anaconda3\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=32, activation="relu", kernel_initializer="glorot_uniform")`
#   import sys
# C:\Users\accsu\Anaconda3\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=16, activation="relu", kernel_initializer="glorot_uniform")`
#
# C:\Users\accsu\Anaconda3\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1, activation="sigmoid", kernel_initializer="glorot_uniform")`
#   if __name__ == '__main__':
# Epoch 1/10
# 21986/21986 [==============================] - 5s 233us/step - loss: 0.6661 - acc: 0.6067
# Epoch 2/10
# 21986/21986 [==============================] - 1s 67us/step - loss: 0.6451 - acc: 0.6337
# Epoch 3/10
# 21986/21986 [==============================] - 1s 65us/step - loss: 0.6393 - acc: 0.6371
# Epoch 4/10
# 21986/21986 [==============================] - 1s 66us/step - loss: 0.6355 - acc: 0.6400
# Epoch 5/10
# 21986/21986 [==============================] - 1s 67us/step - loss: 0.6326 - acc: 0.6419
# Epoch 6/10
# 21986/21986 [==============================] - 1s 59us/step - loss: 0.6299 - acc: 0.6446
# Epoch 7/10
# 21986/21986 [==============================] - 1s 62us/step - loss: 0.6282 - acc: 0.6435
# Epoch 8/10
# 21986/21986 [==============================] - 1s 62us/step - loss: 0.6256 - acc: 0.6467
# Epoch 9/10
# 21986/21986 [==============================] - 2s 69us/step - loss: 0.6237 - acc: 0.6501
# Epoch 10/10
# 21986/21986 [==============================] - 2s 68us/step - loss: 0.6221 - acc: 0.6493

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5) * 1
y_pred
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [1],
#        [0]])

# %%
cm = confusion_matrix(y_test,y_pred)
print(cm)
print((cm[0,0]+cm[1,1])/(cm[0,1]+cm[1,0]+cm[0,0]+cm[1,1]))
# Out:
# [[1049  283]
#  [ 649  462]]
# 0.618501841997544

# %%
y_train.shape
# Out:
# (19543,)

# %%
y_test.shape
# Out:
# (4886,)

# %%
data.shape
# Out:
# (30697, 14)

# %%
import seaborn as sns
correlation_matrix = data.corr()
fig = plt.figure(figsize = (12,9))
sns.heatmap(correlation_matrix,vmax = 0.8,square = True)
plt.show()

# %%
test.head()
# Out:
#     shot_id_number  location_x  remaining_min  power_of_shot  knockout_match  \
# 0              1.0       167.0           10.0            1.0             0.0
# 7              8.0         1.0            8.0            3.0             0.0
# 16            17.0         0.0            0.0            1.0             0.0
# 19            20.0         0.0           10.0            3.0             0.0
# 21            22.0       134.0            9.0            3.0             0.0
#
#     game_season  remaining_sec  area_of_shot  shot_basics  range_of_shot  \
# 0             4           27.0             5            4              0
# 7             4            5.0             0            0              4
# 16            4            1.0             1            0              4
# 19            4           46.0             0            4              4
# 21            4            4.0             4            4              0
#
#     home_or_away  type_of_shot  is_goal
# 0            1.0            24      NaN
# 7            1.0            23      NaN
# 16           0.0            34      NaN
# 19           0.0            34      NaN
# 21           0.0            17      NaN

# %%
test.shape
test = test.drop(columns = ['day','month','year','location_y','distance_of_shot'])
test.head()
# Out:
#     shot_id_number  location_x  remaining_min  power_of_shot  knockout_match  \
# 0              1.0       167.0           10.0            1.0             0.0
# 7              8.0         1.0            8.0            3.0             0.0
# 16            17.0         0.0            0.0            1.0             0.0
# 19            20.0         0.0           10.0            3.0             0.0
# 21            22.0       134.0            9.0            3.0             0.0
#
#     game_season  remaining_sec  area_of_shot  shot_basics  range_of_shot  \
# 0             4           27.0             5            4              0
# 7             4            5.0             0            0              4
# 16            4            1.0             1            0              4
# 19            4           46.0             0            4              4
# 21            4            4.0             4            4              0
#
#     home_or_away  type_of_shot  is_goal
# 0            1.0            24      NaN
# 7            1.0            23      NaN
# 16           0.0            34      NaN
# 19           0.0            34      NaN
# 21           0.0            17      NaN

# %%
"""
y  = test.iloc[:,15].values
test = test.drop(columns = ['is_goal'])
X = test.iloc[:,:].values
print(X.shape)
print(y.shape)

"""
y  = test.iloc[:,:-1].values
test  = test.drop(columns = ['is_goal'])
X = test.iloc[:,:].values
print(X.shape)
print(y.shape)
# Out:
# (6268, 12)
# (6268, 12)

# %%
X = onehotencoder.transform(X[:,1:]).toarray()

# %%
data = scaler.transform(X[:,1:])
#data = onehotencoder.transform(data[:,1:]).toarray()

# %%
y_pred = classifier.predict(data)

# %%
y_pred
# Out:
# array([[0.24848762],
#        [0.41709626],
#        [0.4420074 ],
#        ...,
#        [0.8510671 ],
#        [0.3105303 ],
#        [0.36263666]], dtype=float32)

# %%
shot_ids = test.iloc[:,0:1].values
shot_ids
y_num = np.hstack((shot_ids ,y_pred))
#y_num = y_num.reshape((6268,2))
y_num.shape
# Out:
# (6268, 2)

# %%
y_nb_sol = pd.DataFrame(y_num,columns=['shot_id_number','is_goal']).to_csv('y__nn2.csv')

# %%
y_num
# Out:
# array([[ 1.        ,  8.        ],
#        [17.        , 20.        ],
#        [22.        , 33.        ],
#        ...,
#        [ 0.72618842,  0.72618842],
#        [ 0.72618842,  0.72618842],
#        [ 0.72618842,  0.72618842]])
